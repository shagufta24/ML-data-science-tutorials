# %% [markdown]
# # Working with Strings in Pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading datasets
happiness2015 = pd.read_csv("datasets/World_Happiness_2015.csv")
world_dev = pd.read_csv("datasets/World_dev.csv")

# %%
happiness2015.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201

# %%
world_dev.head(2)
# Out:
#   CountryCode    ShortName    TableName                      LongName  \
# 0         AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 1         ALB      Albania      Albania           Republic of Albania
#
#   Alpha2Code    CurrencyUnit  \
# 0         AF  Afghan afghani
# 1         AL    Albanian lek
#
#                                         SpecialNotes                 Region  \
# 0  Fiscal year end: March 20; reporting period fo...             South Asia
# 1                                                NaN  Europe & Central Asia
#
#            IncomeGroup Wb2Code  ...      GovernmentAccountingConcept  \
# 0           Low income      AF  ...  Consolidated central government
# 1  Upper middle income      AL  ...     Budgetary central government
#
#                ImfDataDisseminationStandard LatestPopulationCensus  \
# 0  General Data Dissemination System (GDDS)                   1979
# 1  General Data Dissemination System (GDDS)                   2011
#
#                                LatestHouseholdSurvey  \
# 0  Multiple Indicator Cluster Survey (MICS), 2010/11
# 1       Demographic and Health Survey (DHS), 2008/09
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                       NaN                  2013/14                  NaN
# 1                       Yes                     2012               2011.0
#
#   LatestTradeData LatestWaterWithdrawalData
# 0          2013.0                    2000.0
# 1          2013.0                    2006.0
#
# [2 rows x 31 columns]

# %%
# Merging the two dataframes using pd.merge()

merged = pd.merge(left=happiness2015, 
                  right=world_dev, 
                  how='left', 
                  left_on='Country', 
                  right_on='ShortName')

# %%
# Renaming column

col_renaming = {'SourceOfMostRecentIncomeAndExpenditureData': 'IESurvey'}
merged.rename(col_renaming, axis=1, inplace=True)

merged.head(3)
# Out:
#        Country        Region_x  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 0                   0.94143  0.66557                        0.41978  ...
# 1                   0.94784  0.62877                        0.14145  ...
# 2                   0.87464  0.64938                        0.48357  ...
#
#        GovernmentAccountingConcept  \
# 0  Consolidated central government
# 1  Consolidated central government
# 2  Consolidated central government
#
#                  ImfDataDisseminationStandard LatestPopulationCensus  \
# 0  Special Data Dissemination Standard (SDDS)                   2010
# 1  Special Data Dissemination Standard (SDDS)                   2011
# 2  Special Data Dissemination Standard (SDDS)                   2011
#
#   LatestHouseholdSurvey                                        IESurvey  \
# 0                   NaN  Expenditure survey/budget survey (ES/BS), 2004
# 1                   NaN         Integrated household survey (IHS), 2010
# 2                   NaN                Income tax registers (ITR), 2010
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                       Yes                     2008               2010.0
# 1                       Yes                     2010               2005.0
# 2                       Yes                     2010               2010.0
#
#   LatestTradeData LatestWaterWithdrawalData
# 0          2013.0                    2000.0
# 1          2013.0                    2005.0
# 2          2013.0                    2009.0
#
# [3 rows x 43 columns]

# %% [markdown]
# Perform the following tasks:
#
# 1. Extract the unit of currency from the "CurrencyUnit" column without the leading nationality. For example, instead of "Danish krone", just "krone".
# <br>
# - We could use Python's string.split() method for the extraction.
# <br>
# - To repeat this for each element in the Series, we can use the Series.apply() method.

# %%
merged["CurrencyUnit"]
# Out:
# 0                 Swiss franc
# 1               Iceland krona
# 2                Danish krone
# 3             Norwegian krone
# 4             Canadian dollar
#                 ...
# 153             Rwandan franc
# 154    West African CFA franc
# 155                       NaN
# 156             Burundi franc
# 157    West African CFA franc
# Name: CurrencyUnit, Length: 158, dtype: object

# %%
# Custom function to extract the last word from a string

def extract_last_word(element):
    return str(element).split()[-1]

# %%
# Apply it to the entire column using Series.apply()

merged['Currency Apply']=merged['CurrencyUnit'].apply(extract_last_word)
merged['Currency Apply']
# Out:
# 0       franc
# 1       krona
# 2       krone
# 3       krone
# 4      dollar
#         ...
# 153     franc
# 154     franc
# 155       nan
# 156     franc
# 157     franc
# Name: Currency Apply, Length: 158, dtype: object

# %% [markdown]
# However, vectorized methods are better than using Series.apply(). Pandas has built in a many vectorized methods that perform the same operations for strings in series as Python string methods.
# <br>
# The full list is here: https://pandas.pydata.org/pandas-docs/stable/text.html#method-summary
# <br><br>
# In this case, we can use:
# - Series.str.split() method to split the string into a list of words.
# - Series.str.get() method to get the word at a given position.

# %%
merged['CurrencyUnit'].str.split()
# Out:
# 0                   [Swiss, franc]
# 1                 [Iceland, krona]
# 2                  [Danish, krone]
# 3               [Norwegian, krone]
# 4               [Canadian, dollar]
#                   ...
# 153               [Rwandan, franc]
# 154    [West, African, CFA, franc]
# 155                            NaN
# 156               [Burundi, franc]
# 157    [West, African, CFA, franc]
# Name: CurrencyUnit, Length: 158, dtype: object

# %%
merged['Currency Vectorized']=merged['CurrencyUnit'].str.split().str.get(-1)
merged['Currency Vectorized']
# Out:
# 0       franc
# 1       krona
# 2       krone
# 3       krone
# 4      dollar
#         ...
# 153     franc
# 154     franc
# 155       NaN
# 156     franc
# 157     franc
# Name: Currency Vectorized, Length: 158, dtype: object

# %% [markdown]
# 2. Compute the length of each string in the CurrencyUnit column.
# <br>
#
# We can use Series.apply() to apply a custom function to find the length of each string in the column.
# <br>
# But what would happen to the null values?

# %%
# Check if there are any missing values
merged['CurrencyUnit'].isnull().sum()
# Out:
# 13

# %%
# Custom function to return the length of each currency unit
def compute_lengths(element):
    return len(str(element))

# Apply it to the column
lengths_apply = merged['CurrencyUnit'].apply(compute_lengths)

# %%
# Check the number of missing values in the result
lengths_apply.value_counts(dropna=False)
# Out:
# 14.0    21
# 4.0     20
# 12.0    17
# 13.0    14
# NaN     13
# 15.0    13
# 16.0    12
# 18.0     9
# 17.0     9
# 11.0     8
# 22.0     7
# 25.0     5
# 19.0     3
# 9.0      2
# 26.0     1
# 23.0     1
# 10.0     1
# 39.0     1
# 20.0     1
# Name: CurrencyUnit, dtype: int64

# %% [markdown]
# There are no missing values in the calculated lengths. In fact, our function treated NaN as a string and returned length=3 for it.<br>
# We have to modify the custom function to ignore the null values.

# %%
def compute_lengths(element):
    if pd.isnull(element):
        pass
    else:
        return len(str(element))
lengths_apply = merged['CurrencyUnit'].apply(compute_lengths)
lengths_apply.value_counts(dropna=False)
# Out:
# 14.0    21
# 4.0     20
# 12.0    17
# 13.0    14
# NaN     13
# 15.0    13
# 16.0    12
# 18.0     9
# 17.0     9
# 11.0     8
# 22.0     7
# 25.0     5
# 19.0     3
# 9.0      2
# 26.0     1
# 23.0     1
# 10.0     1
# 39.0     1
# 20.0     1
# Name: CurrencyUnit, dtype: int64

# %% [markdown]
# Instead of doing this, we can use vectorized method Series.str.len() method to return the length of each element in a column.
# <br>
# **Note**: Vectorized methods automatically exclude missing values!

# %%
lengths=merged['CurrencyUnit'].str.len()
lengths.value_counts(dropna=False)
# Out:
# 14.0    21
# 4.0     20
# 12.0    17
# 13.0    14
# NaN     13
# 15.0    13
# 16.0    12
# 18.0     9
# 17.0     9
# 11.0     8
# 22.0     7
# 25.0     5
# 19.0     3
# 9.0      2
# 26.0     1
# 23.0     1
# 10.0     1
# 39.0     1
# 20.0     1
# Name: CurrencyUnit, dtype: int64

# %% [markdown]
# 3. Search for the substring "national accounts" in the "SpecialNotes column" and select only the rows containing it.
#
# - To parse the elements of a Series to find a string that doesn't appear in the same position in each element, we can use regular expressions, or **regex** for short.
# - A regular expression is a sequence of characters that describes a search pattern, used to match characters in a string.
# - In pandas, regular expression is integrated with vectorized string methods. In this case, we can use Series.str.contains() method to  to see if a specific phrase appeared in a series.
#
#
# Regex docs: https://docs.python.org/3.4/library/re.html

# %%
merged["SpecialNotes"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      Fiscal year end: March 31; reporting period fo...
#                              ...
# 153    Based on official government statistics, natio...
# 154                                                  NaN
# 155                                                  NaN
# 156                                                  NaN
# 157    April 2013 database update: Based on IMF data,...
# Name: SpecialNotes, Length: 158, dtype: object

# %%
# Pattern created using regex
pattern = r"[Nn]ational accounts"

# Matching pattern
national_accounts = merged['SpecialNotes'].str.contains(pattern)
national_accounts
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4      True
#        ...
# 153    True
# 154     NaN
# 155     NaN
# 156     NaN
# 157    True
# Name: SpecialNotes, Length: 158, dtype: object

# %%
# Return the value counts for each value in the Series, including missing values.
national_accounts.value_counts(dropna=False)
# Out:
# NaN      65
# True     54
# False    39
# Name: SpecialNotes, dtype: int64

# %% [markdown]
# Before we use boolean indexing to get all the rows containing "national accounts", we need to get rid of NaN values. So, we change them to False.<br>
# Set the na parameter to False in Series.str.contains() to return False for the NaN values.

# %%
national_accounts=merged['SpecialNotes'].str.contains(pattern, na=False)

# %%
national_accounts.value_counts(dropna=False)
# Out:
# False    104
# True      54
# Name: SpecialNotes, dtype: int64

# %%
# Use boolean indexing to return only the rows that contain 
# "national accounts" or "National accounts" in the SpecialNotes column
merged[national_accounts]
# Out:
#                   Country                         Region_x  Happiness Rank  \
# 4                  Canada                    North America               5
# 7                  Sweden                   Western Europe               8
# 8             New Zealand        Australia and New Zealand               9
# 9               Australia        Australia and New Zealand              10
# 14          United States                    North America              15
# 19   United Arab Emirates  Middle East and Northern Africa              20
# 23              Singapore                Southeastern Asia              24
# 31                Uruguay      Latin America and Caribbean              32
# 33               Thailand                Southeastern Asia              34
# 38                 Kuwait  Middle East and Northern Africa              39
# 45                  Japan                     Eastern Asia              46
# 47                Ecuador      Latin America and Caribbean              48
# 52               Paraguay      Latin America and Caribbean              53
# 56              Nicaragua      Latin America and Caribbean              57
# 62                  Libya  Middle East and Northern Africa              63
# 64                Jamaica      Latin America and Caribbean              65
# 73              Indonesia                Southeastern Asia              74
# 74                Vietnam                Southeastern Asia              75
# 77                Nigeria               Sub-Saharan Africa              78
# 79             Azerbaijan       Central and Eastern Europe              80
# 80               Pakistan                    Southern Asia              81
# 83                  China                     Eastern Asia              84
# 84                 Zambia               Sub-Saharan Africa              85
# 86                 Serbia       Central and Eastern Europe              87
# 89            Philippines                Southeastern Asia              90
# 96                Lesotho               Sub-Saharan Africa              97
# 100             Swaziland               Sub-Saharan Africa             101
# 103               Hungary       Central and Eastern Europe             104
# 108            Bangladesh                    Southern Asia             109
# 109                  Iran  Middle East and Northern Africa             110
# 112          South Africa               Sub-Saharan Africa             113
# 113                 Ghana               Sub-Saharan Africa             114
# 114              Zimbabwe               Sub-Saharan Africa             115
# 115               Liberia               Sub-Saharan Africa             116
# 116                 India                    Southern Asia             117
# 117                 Sudan               Sub-Saharan Africa             118
# 118                 Haiti      Latin America and Caribbean             119
# 120                 Nepal                    Southern Asia             121
# 121              Ethiopia               Sub-Saharan Africa             122
# 122          Sierra Leone               Sub-Saharan Africa             123
# 124                 Kenya               Sub-Saharan Africa             125
# 127              Botswana               Sub-Saharan Africa             128
# 128               Myanmar                Southeastern Asia             129
# 130                Malawi               Sub-Saharan Africa             131
# 133              Bulgaria       Central and Eastern Europe             134
# 134                 Egypt  Middle East and Northern Africa             135
# 135                 Yemen  Middle East and Northern Africa             136
# 136                Angola               Sub-Saharan Africa             137
# 140                Uganda               Sub-Saharan Africa             141
# 143                 Niger               Sub-Saharan Africa             144
# 148                  Chad               Sub-Saharan Africa             149
# 152           Afghanistan                    Southern Asia             153
# 153                Rwanda               Sub-Saharan Africa             154
# 157                  Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 4              7.427         0.03553                   1.32629  1.32261
# 7              7.364         0.03157                   1.33171  1.28907
# 8              7.286         0.03371                   1.25018  1.31967
# 9              7.284         0.04083                   1.33358  1.30923
# 14             7.119         0.03839                   1.39451  1.24711
# 19             6.901         0.03729                   1.42727  1.12575
# 23             6.798         0.03780                   1.52186  1.02000
# 31             6.485         0.04539                   1.06166  1.20890
# 33             6.455         0.03557                   0.96690  1.26504
# 38             6.295         0.04456                   1.55422  1.16594
# 45             5.987         0.03581                   1.27074  1.25712
# 47             5.975         0.04528                   0.86402  0.99903
# 52             5.878         0.04563                   0.75985  1.30477
# 56             5.828         0.05371                   0.59325  1.14184
# 62             5.754         0.07832                   1.13145  1.11862
# 64             5.709         0.13693                   0.81038  1.15102
# 73             5.399         0.02596                   0.82827  1.08708
# 74             5.360         0.03107                   0.63216  0.91226
# 77             5.268         0.04192                   0.65435  0.90432
# 79             5.212         0.03363                   1.02389  0.93793
# 80             5.194         0.03726                   0.59543  0.41411
# 83             5.140         0.02424                   0.89012  0.94675
# 84             5.129         0.06988                   0.47038  0.91612
# 86             5.123         0.04864                   0.92053  1.00964
# 89             5.073         0.04934                   0.70532  1.03516
# 96             4.898         0.09438                   0.37545  1.04103
# 100            4.867         0.08742                   0.71206  1.07284
# 103            4.800         0.06107                   1.12094  1.20215
# 108            4.694         0.03077                   0.39753  0.43106
# 109            4.686         0.04449                   1.00880  0.54447
# 112            4.642         0.04585                   0.92049  1.18468
# 113            4.633         0.04742                   0.54558  0.67954
# 114            4.610         0.04290                   0.27100  1.03276
# 115            4.571         0.11068                   0.07120  0.78968
# 116            4.565         0.02043                   0.64499  0.38174
# 117            4.550         0.06740                   0.52107  1.01404
# 118            4.518         0.07331                   0.26673  0.74302
# 120            4.514         0.03607                   0.35997  0.86449
# 121            4.512         0.03780                   0.19073  0.60406
# 122            4.507         0.07068                   0.33024  0.95571
# 124            4.419         0.04734                   0.36471  0.99876
# 127            4.332         0.04934                   0.99355  1.10464
# 128            4.307         0.04351                   0.27108  0.70905
# 130            4.292         0.06130                   0.01604  0.41134
# 133            4.218         0.04828                   1.01216  1.10614
# 134            4.194         0.03260                   0.88180  0.74700
# 135            4.077         0.04367                   0.54649  0.68093
# 136            4.033         0.04758                   0.75778  0.86040
# 140            3.931         0.04317                   0.21102  1.13299
# 143            3.845         0.03602                   0.06940  0.77265
# 148            3.667         0.03830                   0.34193  0.76062
# 152            3.575         0.03084                   0.31982  0.30285
# 153            3.465         0.03464                   0.22208  0.77370
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  ...  \
# 4                     0.90563  0.63297                        0.32957  ...
# 7                     0.91087  0.65980                        0.43844  ...
# 8                     0.90837  0.63938                        0.42922  ...
# 9                     0.93156  0.65124                        0.35637  ...
# 14                    0.86179  0.54604                        0.15890  ...
# 19                    0.80925  0.64157                        0.38583  ...
# 23                    1.02525  0.54252                        0.49210  ...
# 31                    0.81160  0.60362                        0.24558  ...
# 33                    0.73850  0.55664                        0.03187  ...
# 38                    0.72492  0.55499                        0.25609  ...
# 45                    0.99111  0.49615                        0.18060  ...
# 47                    0.79075  0.48574                        0.18090  ...
# 52                    0.66098  0.53899                        0.08242  ...
# 56                    0.74314  0.55475                        0.19317  ...
# 62                    0.70380  0.41668                        0.11023  ...
# 64                    0.68741  0.50442                        0.02299  ...
# 73                    0.63793  0.46611                        0.00000  ...
# 74                    0.74676  0.59444                        0.10441  ...
# 77                    0.16007  0.34334                        0.04030  ...
# 79                    0.64045  0.37030                        0.16065  ...
# 80                    0.51466  0.12102                        0.10464  ...
# 83                    0.81658  0.51697                        0.02781  ...
# 84                    0.29924  0.48827                        0.12468  ...
# 86                    0.74836  0.20107                        0.02617  ...
# 89                    0.58114  0.62545                        0.12279  ...
# 96                    0.07612  0.31767                        0.12504  ...
# 100                   0.07566  0.30658                        0.03060  ...
# 103                   0.75905  0.32112                        0.02758  ...
# 108                   0.60164  0.40820                        0.12569  ...
# 109                   0.69805  0.30033                        0.05863  ...
# 112                   0.27688  0.33207                        0.08884  ...
# 113                   0.40132  0.42342                        0.04355  ...
# 114                   0.33475  0.25861                        0.08079  ...
# 115                   0.34201  0.28531                        0.06232  ...
# 116                   0.51529  0.39786                        0.08492  ...
# 117                   0.36878  0.10081                        0.14660  ...
# 118                   0.38847  0.24425                        0.17175  ...
# 120                   0.56874  0.38282                        0.05907  ...
# 121                   0.44055  0.43450                        0.15048  ...
# 122                   0.00000  0.40840                        0.08786  ...
# 124                   0.41435  0.42215                        0.05839  ...
# 127                   0.04776  0.49495                        0.12474  ...
# 128                   0.48246  0.44017                        0.19034  ...
# 130                   0.22562  0.43054                        0.06977  ...
# 133                   0.76649  0.30587                        0.00872  ...
# 134                   0.61712  0.17288                        0.06324  ...
# 135                   0.40064  0.35571                        0.07854  ...
# 136                   0.16683  0.10384                        0.07122  ...
# 140                   0.33861  0.45727                        0.07267  ...
# 143                   0.29707  0.47692                        0.15639  ...
# 148                   0.15010  0.23501                        0.05269  ...
# 152                   0.30335  0.23414                        0.09719  ...
# 153                   0.42864  0.59201                        0.55191  ...
# 157                   0.28443  0.36453                        0.10731  ...
#
#      LatestPopulationCensus  \
# 4                      2011
# 7                      2011
# 8                      2013
# 9                      2011
# 14                     2010
# 19                     2010
# 23                     2010
# 31                     2011
# 33                     2010
# 38                     2011
# 45                     2010
# 47                     2010
# 52                     2012
# 56                     2005
# 62                     2006
# 64                     2011
# 73                     2010
# 74                     2009
# 77                     2006
# 79                     2009
# 80                     1998
# 83                     2010
# 84                     2010
# 86                     2011
# 89                     2010
# 96                     2006
# 100                    2007
# 103                    2011
# 108                    2011
# 109                    2011
# 112                    2011
# 113                    2010
# 114                    2012
# 115                    2008
# 116                    2011
# 117                    2008
# 118                    2003
# 120                    2011
# 121                    2007
# 122                    2004
# 124                    2009
# 127                    2011
# 128                    2014
# 130                    2008
# 133                    2011
# 134                    2006
# 135                    2004
# 136                    2014
# 140                    2014
# 143                    2012
# 148                    2009
# 152                    1979
# 153                    2012
# 157                    2010
#
#                                  LatestHouseholdSurvey  \
# 4                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 14                                                 NaN
# 19                     World Health Survey (WHS), 2003
# 23                  National Health Survey (NHS), 2010
# 31   Multiple Indicator Cluster Survey (MICS), 2012/13
# 33      Multiple Indicator Cluster Survey (MICS), 2012
# 38                    Family Health Survey (FHS), 1996
# 45                                                 NaN
# 47              Reproductive Health Survey (RHS), 2004
# 52              Reproductive Health Survey (RHS), 2008
# 56         Reproductive Health Survey (RHS), 2006/2007
# 62                    Family Health Survey (FHS), 2007
# 64      Multiple Indicator Cluster Survey (MICS), 2011
# 73           Demographic and Health Survey (DHS), 2012
# 74   Multiple Indicator Cluster Survey (MICS), 2013/14
# 77           Demographic and Health Survey (DHS), 2013
# 79           Demographic and Health Survey (DHS), 2006
# 80        Demographic and Health Survey (DHS), 2012/13
# 83   National Sample Survey on Population Change (N...
# 84        Demographic and Health Survey (DHS), 2013/14
# 86      Multiple Indicator Cluster Survey (MICS), 2014
# 89           Demographic and Health Survey (DHS), 2013
# 96           Demographic and Health Survey (DHS), 2014
# 100     Multiple Indicator Cluster Survey (MICS), 2014
# 103                    World Health Survey (WHS), 2003
# 108  Demographic and Health Survey (DHS), 2014; HIV...
# 109  Iran's Multiple Indicator Demographic and Heal...
# 112  Demographic and Health Survey (DHS), 2003; Wor...
# 113          Demographic and Health Survey (DHS), 2014
# 114     Multiple Indicator Cluster Survey (MICS), 2014
# 115          Demographic and Health Survey (DHS), 2013
# 116       Demographic and Health Survey (DHS), 2005/06
# 117     Multiple Indicator Cluster Survey (MICS), 2014
# 118  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 120     Multiple Indicator Cluster Survey (MICS), 2014
# 121  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 122  Demographic and Health Survey (DHS), 2013; Mal...
# 124          Demographic and Health Survey (DHS), 2014
# 127     Multiple Indicator Cluster Survey (MICS), 2000
# 128  Multiple Indicator Cluster Survey (MICS), 2009/10
# 130               Malaria Indicator Survey (MIS), 2014
# 133  Living Standards Measurement Study Survey (LSM...
# 134          Demographic and Health Survey (DHS), 2014
# 135          Demographic and Health Survey (DHS), 2013
# 136               Malaria Indicator Survey (MIS), 2011
# 140               Malaria Indicator Survey (MIS), 2014
# 143          Demographic and Health Survey (DHS), 2012
# 148          Demographic and Health Survey (DHS), 2014
# 152  Multiple Indicator Cluster Survey (MICS), 2010/11
# 153               Malaria Indicator Survey (MIS), 2013
# 157       Demographic and Health Survey (DHS), 2013/14
#
#                                               IESurvey  \
# 4                       Labor force survey (LFS), 2010
# 7                             Income survey (IS), 2005
# 8                                                  NaN
# 9       Expenditure survey/budget survey (ES/BS), 2003
# 14                      Labor force survey (LFS), 2010
# 19                                                 NaN
# 23                                                 NaN
# 31             Integrated household survey (IHS), 2013
# 33             Integrated household survey (IHS), 2011
# 38                                                 NaN
# 45             Integrated household survey (IHS), 2008
# 47             Integrated household survey (IHS), 2013
# 52             Integrated household survey (IHS), 2013
# 56   Living Standards Measurement Study Survey (LSM...
# 62                                                 NaN
# 64   Living Standards Measurement Study Survey (LSM...
# 73             Integrated household survey (IHS), 2013
# 74             Integrated household survey (IHS), 2012
# 77          Integrated household survey (IHS), 2009/10
# 79   Living Standards Measurement Study Survey (LSM...
# 80          Integrated household survey (IHS), 2010/11
# 83             Integrated household survey (IHS), 2012
# 84             Integrated household survey (IHS), 2010
# 86             Integrated household survey (IHS), 2011
# 89      Expenditure survey/budget survey (ES/BS), 2012
# 96      Expenditure survey/budget survey (ES/BS), 2010
# 100  Expenditure survey/budget survey (ES/BS), 2009/10
# 103            Integrated household survey (IHS), 2012
# 108            Integrated household survey (IHS), 2010
# 109     Expenditure survey/budget survey (ES/BS), 2005
# 112  Expenditure survey/budget survey (ES/BS), 2010/11
# 113  Living Standards Measurement Study Survey (LSM...
# 114         Integrated household survey (IHS), 2011/12
# 115  Core Welfare Indicator Questionnaire Survey (C...
# 116         Integrated household survey (IHS), 2011/12
# 117     Expenditure survey/budget survey (ES/BS), 2009
# 118            Integrated household survey (IHS), 2012
# 120  Living Standards Measurement Study Survey (LSM...
# 121  Expenditure survey/budget survey (ES/BS), 2010/11
# 122            Integrated household survey (IHS), 2011
# 124         Integrated household survey (IHS), 2005/06
# 127  Expenditure survey/budget survey (ES/BS), 2009/10
# 128                                                NaN
# 130         Integrated household survey (IHS), 2010/11
# 133     Expenditure survey/budget survey (ES/BS), 2012
# 134     Expenditure survey/budget survey (ES/BS), 2011
# 135     Expenditure survey/budget survey (ES/BS), 2005
# 136         Integrated household survey (IHS), 2008/09
# 140         Integrated household survey (IHS), 2012/13
# 143  Core Welfare Indicator Questionnaire Survey (C...
# 148                         Priority survey (PS), 2011
# 152            Integrated household survey (IHS), 2008
# 153         Integrated household survey (IHS), 2010/11
# 157  Core Welfare Indicator Questionnaire Survey (C...
#
#     VitalRegistrationComplete              LatestAgriculturalCensus  \
# 4                         Yes                                  2011
# 7                         Yes                                  2010
# 8                         Yes                                  2012
# 9                         Yes                                  2011
# 14                        Yes                                  2012
# 19                        NaN                                  2012
# 23                        Yes                                   NaN
# 31                        Yes                                  2011
# 33                        NaN                                  2013
# 38                        Yes                                   NaN
# 45                        Yes                                  2010
# 47                        NaN                               2013/15
# 52                        NaN                                  2008
# 56                        NaN                                  2011
# 62                        NaN                             2013/2014
# 64                        NaN                                  2007
# 73                        NaN                                  2013
# 74                        Yes                            2011/ 2012
# 77                        NaN                                  2013
# 79                        Yes                                  2015
# 80                        NaN                                  2010
# 83                        NaN                                  2007
# 84                        NaN  2010. Population and Housing Census.
# 86                        Yes                                  2012
# 89                        Yes                                  2012
# 96                        NaN                                  2010
# 100                       NaN  2007. Population and Housing Census.
# 103                       Yes                                  2010
# 108                       NaN                                  2008
# 109                       Yes                                  2013
# 112                       NaN                                  2007
# 113                       NaN                            2013/ 2014
# 114                       NaN                                   NaN
# 115                       NaN  2008. Population and Housing Census.
# 116                       NaN                                  2011
# 117                       NaN                            2013/ 2014
# 118                       NaN                            2008/ 2009
# 120                       NaN                            2011/ 2012
# 121                       NaN                                   NaN
# 122                       NaN                                   NaN
# 124                       NaN  2009. Population and Housing Census.
# 127                       NaN  2011. Population and Housing Census.
# 128                       NaN                                  2010
# 130                       NaN                            2006/ 2007
# 133                       Yes                                  2010
# 134                       Yes                             2009/2010
# 135                       NaN                                   NaN
# 136                       NaN                                  2015
# 140                       NaN                            2008/ 2009
# 143                       NaN                             2004-2008
# 148                       NaN                            2010/ 2011
# 152                       NaN                               2013/14
# 153                       NaN                                  2008
# 157                       NaN                             2011/2012
#
#     LatestIndustrialData LatestTradeData LatestWaterWithdrawalData  \
# 4                 2011.0          2013.0                    1986.0
# 7                 2010.0          2013.0                    2007.0
# 8                 2010.0          2013.0                    2002.0
# 9                 2011.0          2013.0                    2000.0
# 14                2008.0          2013.0                    2005.0
# 19                2010.0          2011.0                    2005.0
# 23                2011.0          2013.0                    1975.0
# 31                2009.0          2013.0                    2000.0
# 33                2006.0          2013.0                    2007.0
# 38                2011.0          2013.0                    2002.0
# 45                2010.0          2013.0                    2001.0
# 47                2008.0          2013.0                    2005.0
# 52                2002.0          2013.0                    2012.0
# 56                   NaN          2013.0                    2011.0
# 62                   NaN          2010.0                    2000.0
# 64                   NaN          2013.0                    1993.0
# 73                2011.0          2013.0                    2000.0
# 74                2011.0          2013.0                    2005.0
# 77                   NaN          2013.0                    2005.0
# 79                2011.0          2013.0                    2012.0
# 80                2006.0          2013.0                    2008.0
# 83                2007.0          2013.0                    2005.0
# 84                   NaN          2013.0                    2002.0
# 86                2011.0             NaN                    2009.0
# 89                2008.0          2013.0                    2009.0
# 96                   NaN          2009.0                    2000.0
# 100                  NaN          2007.0                    2000.0
# 103               2010.0          2013.0                    2007.0
# 108                  NaN          2007.0                    2008.0
# 109               2010.0          2011.0                    2004.0
# 112               2010.0          2013.0                    2000.0
# 113               2003.0          2013.0                    2000.0
# 114                  NaN          2013.0                    2002.0
# 115                  NaN             NaN                    2000.0
# 116               2010.0          2013.0                    2010.0
# 117               2001.0          2011.0                    2011.0
# 118                  NaN          1997.0                    2000.0
# 120               2008.0          2013.0                    2006.0
# 121               2009.0          2013.0                    2002.0
# 122               2008.0          2002.0                    2005.0
# 124               2011.0          2010.0                    2003.0
# 127               2011.0          2013.0                    2000.0
# 128                  NaN          2010.0                    2000.0
# 130               2010.0          2013.0                    2005.0
# 133               2011.0          2013.0                    2009.0
# 134               2010.0          2013.0                    2000.0
# 135               2009.0          2013.0                    2005.0
# 136                  NaN             NaN                    2005.0
# 140                  NaN          2013.0                    2002.0
# 143               2002.0          2013.0                    2005.0
# 148                  NaN          1995.0                    2005.0
# 152                  NaN          2013.0                    2000.0
# 153                  NaN          2013.0                    2000.0
# 157                  NaN          2013.0                    2002.0
#
#     Currency Apply Currency Vectorized
# 4           dollar              dollar
# 7            krona               krona
# 8           dollar              dollar
# 9           dollar              dollar
# 14          dollar              dollar
# 19          dirham              dirham
# 23          dollar              dollar
# 31            peso                peso
# 33            baht                baht
# 38           dinar               dinar
# 45             yen                 yen
# 47          dollar              dollar
# 52         guarani             guarani
# 56         cordoba             cordoba
# 62           dinar               dinar
# 64          dollar              dollar
# 73          rupiah              rupiah
# 74            dong                dong
# 77           naira               naira
# 79           manat               manat
# 80           rupee               rupee
# 83            yuan                yuan
# 84          kwacha              kwacha
# 86           dinar               dinar
# 89            peso                peso
# 96            loti                loti
# 100      lilangeni           lilangeni
# 103         forint              forint
# 108           taka                taka
# 109           rial                rial
# 112           rand                rand
# 113           cedi                cedi
# 114         dollar              dollar
# 115         dollar              dollar
# 116          rupee               rupee
# 117          pound               pound
# 118         gourde              gourde
# 120          rupee               rupee
# 121           birr                birr
# 122          leone               leone
# 124       shilling            shilling
# 127           pula                pula
# 128           kyat                kyat
# 130         kwacha              kwacha
# 133            lev                 lev
# 134          pound               pound
# 135           rial                rial
# 136         kwanza              kwanza
# 140       shilling            shilling
# 143          franc               franc
# 148          franc               franc
# 152        afghani             afghani
# 153          franc               franc
# 157          franc               franc
#
# [54 rows x 45 columns]

# %% [markdown]
# Some more regex patterns:
# - A character that could be a range of numbers: r"[0-9]"
# - A character that could be a range of letters: r"[a-z]" or r"[A-Z]"
#
# {n} indicates repetition n times.
# - A three character substring that starts with a number between 1 and 6 and ends with two letters of any kind: r"[1-6][a-z][a-z]" = r"[1-6][a-z]{2}"

# %% [markdown]
# 4. Match all the years from the "SpecialNotes" column and extract them.
#
# - To extract part of a string that matches a pattern, we can use **regex**.
# - In this case, we can use Series.str.extract() method to  extract years from the SpecialNotes column.
# - **Capturing group** - the pattern enclosed by the parantheses, for example ([1-9][0-9]{3})
# - If the capturing group is not present, the value is set to NaN.

# %%
# Pattern to be matched
pattern =r"([1-9][0-9]{3})"

# Match and extract
years=merged['SpecialNotes'].str.extract(pattern)
years
# Out:
#         0
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 153  2006
# 154   NaN
# 155   NaN
# 156   NaN
# 157  2013
#
# [158 rows x 1 columns]
